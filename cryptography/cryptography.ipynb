# %%
# Find the flag using ROT13

text = "cvpbPGS{arkg_gvzr_V'yy_gel_2_ebhaqf_bs_ebg13_hyLicInt}"
ans = ""
for ascii in [ord(char) for char in text]:
    if ascii >= 65 and ascii <= 90:
        if ascii >= 78:
            ans += chr(ascii - 13)
        else:
            ans += chr(ascii + 13)
    elif ascii >= 97 and ascii <= 122:
        if ascii >= 110:
            ans += chr(ascii - 13)
        else:
            ans += chr(ascii + 13)
    else:
        ans += chr(ascii)

print(ans)

# Should produce "picoCTF{next_time_I'll_try_2_rounds_of_rot13_ulYvpVag}"
# Out:
# picoCTF{next_time_I'll_try_2_rounds_of_rot13_ulYvpVag}
